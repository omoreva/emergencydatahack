# %%
import sklearn.datasets as datasets
import pandas as pd
import plotly
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import *
from sklearn.model_selection import *
from sklearn.svm import *
from sklearn.ensemble import *
from sklearn.tree import *
from sklearn.naive_bayes import *
from sklearn.neighbors import *
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# # Data exploration - Iris dataset

# %%
iris_dataset = datasets.load_iris()

# %%
print(iris_dataset.keys())

print(iris_dataset['target'], "\n-n\n", iris_dataset['target_names'], "\n-n\n", iris_dataset['DESCR'], "\n-n\n", iris_dataset['feature_names'], "\n-n\n", iris_dataset['filename'])

# %% [markdown]
# ## Transform the data into the dataframe

# %%
df = pd.DataFrame(columns=iris_dataset['feature_names'], data=iris_dataset['data'])

# %%
df['label'] = [iris_dataset['target_names'][i] for i in iris_dataset['target']]

# %% [markdown]
# ## Basic information about the data

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)      label
# 0                  5.1               3.5  ...               0.2     setosa
# 1                  4.9               3.0  ...               0.2     setosa
# 2                  4.7               3.2  ...               0.2     setosa
# 3                  4.6               3.1  ...               0.2     setosa
# 4                  5.0               3.6  ...               0.2     setosa
# ..                 ...               ...  ...               ...        ...
# 145                6.7               3.0  ...               2.3  virginica
# 146                6.3               2.5  ...               1.9  virginica
# 147                6.5               3.0  ...               2.0  virginica
# 148                6.2               3.4  ...               2.3  virginica
# 149                5.9               3.0  ...               1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# count         150.000000        150.000000         150.000000        150.000000
# mean            5.843333          3.057333           3.758000          1.199333
# std             0.828066          0.435866           1.765298          0.762238
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.350000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %%
df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# label                 object
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepal length (cm)  sepal width (cm)  ...  petal width (cm)      label
# 0                  5.1               3.5  ...               0.2     setosa
# 1                  4.9               3.0  ...               0.2     setosa
# 2                  4.7               3.2  ...               0.2     setosa
# 3                  4.6               3.1  ...               0.2     setosa
# 4                  5.0               3.6  ...               0.2     setosa
# ..                 ...               ...  ...               ...        ...
# 145                6.7               3.0  ...               2.3  virginica
# 146                6.3               2.5  ...               1.9  virginica
# 147                6.5               3.0  ...               2.0  virginica
# 148                6.2               3.4  ...               2.3  virginica
# 149                5.9               3.0  ...               1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df['label'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: label, dtype: int64

# %% [markdown]
# ## Print some plots to see if data is linearly seperable

# %%
list_of_titles = []
for x in iris_dataset['feature_names']:
  for y in iris_dataset['feature_names']:
    list_of_titles.append(x+" "+y)

# %%
fig = make_subplots(rows=4, cols=4, subplot_titles=list_of_titles)
colorsIdx = {'setosa': 'red', 'virginica': 'green', 'versicolor':'blue'}
colors = df['label'].map(colorsIdx)
for idx_x, x_col_name in enumerate(iris_dataset['feature_names']):
  for idx_y, y_col_name in enumerate(iris_dataset['feature_names']):
    fig.add_trace(
        go.Scatter(x=df[x_col_name], y=df[y_col_name], text=df['label'], mode='markers', marker=dict(size=5, color=colors), name=x_col_name+" "+y_col_name ), row=idx_x+1, col=idx_y+1
    )

# %%
fig.update_layout(height=1200, width=1800, title_text="Side By Side Subplots")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4d77d03b-d339-4a7c-960d-a8006e1bad7d" class="plotly-graph-div" style="height:1200px; width:1800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4d77d03b-d339-4a7c-960d-a8006e1bad7d")) {
#                     Plotly.newPlot(
#                         '4d77d03b-d339-4a7c-960d-a8006e1bad7d',
# ...

# %%
sns.pairplot(df, hue='label')

# %% [markdown]
# # Classification task using logistic regression

# %% [markdown]
# * Logistic regression could be used for binary classification
# * For multiclass classification sklearn uses one-vs-rest (OvR) method
# * Good for the linearly separable classes
#
# As we see from plots, iris data is linearly separated, so logistic regression algorithm will work great here.

# %%
# prepare X, y for model training

X = df.copy()
del X['label']
X = X.to_numpy()


y = iris_dataset['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
lr = LogisticRegression(random_state=0).fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
lr.score(X_test, y_test)
# Out:
# 1.0

# %%
y_pred = lr.predict(X_test)

# %%
print(classification_report(y_test, y_pred, target_names=iris_dataset['target_names']))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        15
#    virginica       1.00      1.00      1.00        16
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50

# %% [markdown]
# The accuracy of the model on the test data is great, precision, recall and f1-score are perfect. Let's try to use another dataset to see how logistic regression will deal with more complicated data

# %% [markdown]
# # Data Exploration - Wine Dataset

# %%
wine_dataset = datasets.load_wine()

# %%
# transform data into the dataframe

df2 = pd.DataFrame(columns=wine_dataset['feature_names'], data=wine_dataset['data'])
df2['label'] = [wine_dataset['target_names'][i] for i in wine_dataset['target']]

# %%
sns.pairplot(df2, hue='label')

# %%
corr = df2.corr()

f, ax = plt.subplots(figsize=(10, 12))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
_ = sns.heatmap(corr, cmap="YlGn", square=True, ax = ax, annot=True, linewidth=0.1)
plt.title('Pearson correlation of the features', y=1.05, size=15)
# Out:
# Text(0.5, 1.05, 'Pearson correlation of the features')

# %% [markdown]
# malic_acid, alcanity_of_ash and nonflavanoid_phenols are probably the less useless than all other features.

# %%
X = wine_dataset['data']
y = wine_dataset['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=48)

# %%
# prepare configuration for cross validation test harness
seed = 7
# prepare models
models = []
models.append(('SupportVectorClassifier', SVC()))
models.append(('StochasticGradientDecentC', SGDClassifier()))
models.append(('RandomForestClassifier', RandomForestClassifier()))
models.append(('DecisionTreeClassifier', DecisionTreeClassifier()))
models.append(('GaussianNB', GaussianNB()))
models.append(('KNeighborsClassifier', KNeighborsClassifier()))
models.append(('AdaBoostClassifier', AdaBoostClassifier()))
models.append(('LogisticRegression', LogisticRegression()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
   kfold = KFold(n_splits=10, random_state=seed)
   cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
   results.append(cv_results)
   names.append(name)
   msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
   print(msg)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning:
#
# Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
# SupportVectorClassifier: 0.654396 (0.116620)
# StochasticGradientDecentC: 0.690110 (0.084344)
# RandomForestClassifier: 0.977473 (0.034441)
# DecisionTreeClassifier: 0.863187 (0.127975)
# ...

# %%
# boxplot algorithm comparison
fig = plt.figure(figsize=(20, 12))
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# The best model appeared to be GaussianNB
